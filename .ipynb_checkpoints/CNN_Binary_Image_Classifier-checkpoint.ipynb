# %%
import tensorflow as tf
# tf.logging.set_verbosity(tf.logging.ERROR)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1*X GB of memory on the first GPU
#   try:
#     tf.config.experimental.set_virtual_device_configuration(
#         gpus[0],
#         [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=(1024*4))])
#     logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)

# %% [markdown]
# We shall use the ImageDataGenerator class to feed in the training and validation data to the model. This class can also be used to generate augmented data.
#
# To know more about ImageDataGenerator class, visit https://keras.io/preprocessing/image/#imagedatagenerator-class

# %%
train_datagenerator = ImageDataGenerator(rescale=1./255)
test_datagenerator = ImageDataGenerator(rescale=1./255)

train_datagenerator = train_datagenerator.flow_from_directory(
    'train',
    target_size=(128,128),
    batch_size=32,
    class_mode='binary')

test_datagenerator = test_datagenerator.flow_from_directory(
    'test',
    target_size=(128,128),
    batch_size=32,
    class_mode='binary')
# Out:
# Found 392 images belonging to 2 classes.
# Found 258 images belonging to 2 classes.

# %% [markdown]
# Our model will have 3 Convolution2D layers. You can increse or decrease as per your needs.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3),padding='same', activation='relu', input_shape=(128,128,3)),
    tf.keras.layers.MaxPooling2D((2,2),2),
    
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2),2),     
     
    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2),2), 
    
    tf.keras.layers.Conv2D(256, (3,3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2),2),
    
    tf.keras.layers.Conv2D(512, (3,3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2),2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation='relu'),
    
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              8389632
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 9,959,233
# Trainable params: 9,959,233
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# We shall use Adam optimizer with a learning rate of 0.001 (hyperparameter). We choose 'binary_crossentropy' loss as our model is a binary calssifier (i.e, we have only 2 classes)

# %%
# model.compile(loss='binary_crossentropy',
#              optimizer=tf.keras.optimizers.Adam(0.001),
#              metrics=['accuracy'])

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
# opt = tf.keras.optimizers.SGD(learning_rate=0.00001)

model.compile(loss='binary_crossentropy',
             optimizer = opt,
             metrics=['accuracy'])

# %% [markdown]
# At the end of each epoch we can check if the model has reached the required accuracy and terminate the training.

# %%
# DESIRED_ACCURACY = 0.85

# class myCallback(tf.keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs={}):
#     if((logs.get('acc')>DESIRED_ACCURACY) and (logs.get('val_acc')>DESIRED_ACCURACY )):
#       print("\nReached 85% accuracy so cancelling training!")
#       self.model.stop_training = True

# callbacks = myCallback()

class MyThresholdCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(MyThresholdCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None): 
        val_acc = logs["val_accuracy"]
        if val_acc >= self.threshold:
            self.model.stop_training = True

# %% [markdown]
# To know more about fit_generator visit https://keras.io/models/model/#fit_generator

# %%
my_callback = MyThresholdCallback(threshold=0.85)

model.fit_generator(
    train_datagenerator,
    epochs=100,
    validation_data = test_datagenerator,
    callbacks = [my_callback]
    )
# Out:
# Epoch 1/100
# 13/13 [==============================] - 3s 266ms/step - loss: 11.5975 - accuracy: 0.6378 - val_loss: 0.6993 - val_accuracy: 0.3953
ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.5720 - val_accuracy: 0.6783
# Epoch 43/100
# 13/13 [==============================] - 3s 244ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.6224 - val_accuracy: 0.6977
# Epoch 44/100
# 13/13 [==============================] - 3s 264ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.5851 - val_accuracy: 0.7209
# Epoch 45/100
# 13/13 [==============================] - 3s 253ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.6727 - val_accuracy: 0.7016
# Epoch 46/100
# 13/13 [==============================] - 3s 244ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.6412 - val_accuracy: 0.7132
# Epoch 47/100
# 13/13 [==============================] - 3s 234ms/step - loss: 9.5729e-04 - accuracy: 1.0000 - val_loss: 1.6711 - val_accuracy: 0.7093
# Epoch 48/100
# 13/13 [==============================] - 3s 230ms/step - loss: 7.9607e-04 - accuracy: 1.0000 - val_loss: 1.7029 - val_accuracy: 0.7054
# Epoch 49/100
# 13/13 [==============================] - 3s 253ms/step - loss: 7.9809e-04 - accuracy: 1.0000 - val_loss: 1.7019 - val_accuracy: 0.7093
# Epoch 50/100
# 13/13 [==============================] - 3s 250ms/step - loss: 6.2800e-04 - accuracy: 1.0000 - val_loss: 1.7508 - val_accuracy: 0.7054
# Epoch 51/100
# 13/13 [==============================] - 3s 257ms/step - loss: 5.7372e-04 - accuracy: 1.0000 - val_loss: 1.7318 - val_accuracy: 0.7093
# Epoch 52/100
# 13/13 [==============================] - 3s 262ms/step - loss: 5.1147e-04 - accuracy: 1.0000 - val_loss: 1.7615 - val_accuracy: 0.7016
# Epoch 53/100
# 13/13 [==============================] - 3s 253ms/step - loss: 4.8086e-04 - accuracy: 1.0000 - val_loss: 1.7724 - val_accuracy: 0.7016
# Epoch 54/100
# 13/13 [==============================] - 3s 267ms/step - loss: 4.5841e-04 - accuracy: 1.0000 - val_loss: 1.7916 - val_accuracy: 0.7054
# Epoch 55/100
# 13/13 [==============================] - 4s 274ms/step - loss: 4.0904e-04 - accuracy: 1.0000 - val_loss: 1.7864 - val_accuracy: 0.7054
# Epoch 56/100
# 13/13 [==============================] - 3s 262ms/step - loss: 3.8631e-04 - accuracy: 1.0000 - val_loss: 1.7976 - val_accuracy: 0.7093
# Epoch 57/100
# 13/13 [==============================] - 3s 250ms/step - loss: 3.6642e-04 - accuracy: 1.0000 - val_loss: 1.8038 - val_accuracy: 0.7132
# Epoch 58/100
# 13/13 [==============================] - 3s 250ms/step - loss: 3.4295e-04 - accuracy: 1.0000 - val_loss: 1.8195 - val_accuracy: 0.7054
# Epoch 59/100
# 13/13 [==============================] - 3s 229ms/step - loss: 3.2419e-04 - accuracy: 1.0000 - val_loss: 1.8303 - val_accuracy: 0.7093
# Epoch 60/100
# 13/13 [==============================] - 3s 255ms/step - loss: 3.0874e-04 - accuracy: 1.0000 - val_loss: 1.8424 - val_accuracy: 0.7093
# Epoch 61/100
# 13/13 [==============================] - 3s 246ms/step - loss: 2.9175e-04 - accuracy: 1.0000 - val_loss: 1.8520 - val_accuracy: 0.7132
# Epoch 62/100
# 13/13 [==============================] - 3s 253ms/step - loss: 2.8297e-04 - accuracy: 1.0000 - val_loss: 1.8703 - val_accuracy: 0.7093
# Epoch 63/100
# 13/13 [==============================] - 3s 267ms/step - loss: 2.6185e-04 - accuracy: 1.0000 - val_loss: 1.8569 - val_accuracy: 0.7093
# Epoch 64/100
# 13/13 [==============================] - 3s 265ms/step - loss: 2.5029e-04 - accuracy: 1.0000 - val_loss: 1.8717 - val_accuracy: 0.7132
# Epoch 65/100
# 13/13 [==============================] - 3s 250ms/step - loss: 2.4019e-04 - accuracy: 1.0000 - val_loss: 1.8827 - val_accuracy: 0.7132
# Epoch 66/100
# 13/13 [==============================] - 3s 267ms/step - loss: 2.2834e-04 - accuracy: 1.0000 - val_loss: 1.8882 - val_accuracy: 0.7132
# Epoch 67/100
# 13/13 [==============================] - 3s 255ms/step - loss: 2.1981e-04 - accuracy: 1.0000 - val_loss: 1.8993 - val_accuracy: 0.7132
# Epoch 68/100
# 13/13 [==============================] - 3s 263ms/step - loss: 2.0887e-04 - accuracy: 1.0000 - val_loss: 1.8998 - val_accuracy: 0.7132
# Epoch 69/100
# 13/13 [==============================] - 3s 248ms/step - loss: 2.0279e-04 - accuracy: 1.0000 - val_loss: 1.9140 - val_accuracy: 0.7132
# Epoch 70/100
# 13/13 [==============================] - 3s 251ms/step - loss: 1.9313e-04 - accuracy: 1.0000 - val_loss: 1.9253 - val_accuracy: 0.7132
# Epoch 71/100
# 13/13 [==============================] - 3s 247ms/step - loss: 1.8517e-04 - accuracy: 1.0000 - val_loss: 1.9362 - val_accuracy: 0.7132
# Epoch 72/100
# 13/13 [==============================] - 3s 257ms/step - loss: 1.7815e-04 - accuracy: 1.0000 - val_loss: 1.9378 - val_accuracy: 0.7132
# Epoch 73/100
# 13/13 [==============================] - 3s 248ms/step - loss: 1.7351e-04 - accuracy: 1.0000 - val_loss: 1.9328 - val_accuracy: 0.7132
# Epoch 74/100
# 13/13 [==============================] - 3s 255ms/step - loss: 1.6809e-04 - accuracy: 1.0000 - val_loss: 1.9593 - val_accuracy: 0.7132
# Epoch 75/100
# 13/13 [==============================] - 3s 261ms/step - loss: 1.6101e-04 - accuracy: 1.0000 - val_loss: 1.9382 - val_accuracy: 0.7132
# Epoch 76/100
# 13/13 [==============================] - 3s 252ms/step - loss: 1.5239e-04 - accuracy: 1.0000 - val_loss: 1.9623 - val_accuracy: 0.7132
# Epoch 77/100
# 13/13 [==============================] - 3s 262ms/step - loss: 1.4812e-04 - accuracy: 1.0000 - val_loss: 1.9715 - val_accuracy: 0.7132
# Epoch 78/100
# 13/13 [==============================] - 3s 262ms/step - loss: 1.4214e-04 - accuracy: 1.0000 - val_loss: 1.9789 - val_accuracy: 0.7132
# Epoch 79/100
# 13/13 [==============================] - 3s 255ms/step - loss: 1.3661e-04 - accuracy: 1.0000 - val_loss: 1.9779 - val_accuracy: 0.7132
# Epoch 80/100
# 13/13 [==============================] - 3s 248ms/step - loss: 1.3169e-04 - accuracy: 1.0000 - val_loss: 1.9797 - val_accuracy: 0.7132
# Epoch 81/100
# 13/13 [==============================] - 3s 250ms/step - loss: 1.2686e-04 - accuracy: 1.0000 - val_loss: 1.9953 - val_accuracy: 0.7132
# Epoch 82/100
# 13/13 [==============================] - 3s 250ms/step - loss: 1.2574e-04 - accuracy: 1.0000 - val_loss: 1.9971 - val_accuracy: 0.7132
# Epoch 83/100
# 13/13 [==============================] - 3s 251ms/step - loss: 1.2271e-04 - accuracy: 1.0000 - val_loss: 1.9689 - val_accuracy: 0.7171
# Epoch 84/100
# 13/13 [==============================] - 3s 252ms/step - loss: 1.1736e-04 - accuracy: 1.0000 - val_loss: 2.0147 - val_accuracy: 0.7132
# Epoch 85/100
# 13/13 [==============================] - 3s 251ms/step - loss: 1.1982e-04 - accuracy: 1.0000 - val_loss: 2.0312 - val_accuracy: 0.7132
# Epoch 86/100
# 13/13 [==============================] - 3s 248ms/step - loss: 1.0903e-04 - accuracy: 1.0000 - val_loss: 2.0015 - val_accuracy: 0.7171
# Epoch 87/100
# 13/13 [==============================] - 3s 234ms/step - loss: 1.0432e-04 - accuracy: 1.0000 - val_loss: 2.0315 - val_accuracy: 0.7132
# Epoch 88/100
# 13/13 [==============================] - 3s 250ms/step - loss: 1.0155e-04 - accuracy: 1.0000 - val_loss: 2.0422 - val_accuracy: 0.7132
# Epoch 89/100
# 13/13 [==============================] - 3s 251ms/step - loss: 9.9243e-05 - accuracy: 1.0000 - val_loss: 2.0405 - val_accuracy: 0.7132
# Epoch 90/100
# 13/13 [==============================] - 3s 251ms/step - loss: 9.5170e-05 - accuracy: 1.0000 - val_loss: 2.0448 - val_accuracy: 0.7132
# Epoch 91/100
# 13/13 [==============================] - 3s 251ms/step - loss: 9.2424e-05 - accuracy: 1.0000 - val_loss: 2.0418 - val_accuracy: 0.7132
# Epoch 92/100
# 13/13 [==============================] - 3s 256ms/step - loss: 8.9530e-05 - accuracy: 1.0000 - val_loss: 2.0531 - val_accuracy: 0.7132
# Epoch 93/100
# 13/13 [==============================] - 3s 256ms/step - loss: 8.7165e-05 - accuracy: 1.0000 - val_loss: 2.0613 - val_accuracy: 0.7132
# Epoch 94/100
# 13/13 [==============================] - 3s 244ms/step - loss: 8.4798e-05 - accuracy: 1.0000 - val_loss: 2.0593 - val_accuracy: 0.7132
# Epoch 95/100
# 13/13 [==============================] - 3s 236ms/step - loss: 8.2803e-05 - accuracy: 1.0000 - val_loss: 2.0765 - val_accuracy: 0.7132
# Epoch 96/100
# 13/13 [==============================] - 3s 257ms/step - loss: 8.0099e-05 - accuracy: 1.0000 - val_loss: 2.0729 - val_accuracy: 0.7132
# Epoch 97/100
# 13/13 [==============================] - 3s 256ms/step - loss: 7.9804e-05 - accuracy: 1.0000 - val_loss: 2.0791 - val_accuracy: 0.7132
# Epoch 98/100
# 13/13 [==============================] - 3s 255ms/step - loss: 7.6414e-05 - accuracy: 1.0000 - val_loss: 2.0863 - val_accuracy: 0.7132
# Epoch 99/100
# 13/13 [==============================] - 4s 272ms/step - loss: 7.3945e-05 - accuracy: 1.0000 - val_loss: 2.0854 - val_accuracy: 0.7132
# Epoch 100/100
# 13/13 [==============================] - 4s 269ms/step - loss: 7.2798e-05 - accuracy: 1.0000 - val_loss: 2.0953 - val_accuracy: 0.7132

# %%
model.save('Pizza.h5')
